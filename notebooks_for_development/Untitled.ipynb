# %%
import matplotlib.pyplot as plt
import imageio as iio
import numpy as np

# %%
stem = '/Users/bandari/Downloads/publiuc_2/'

# %%
# read an image 
img_dark = iio.imread(stem + 'test_dark_1.png')
img_light = iio.imread(stem + 'test_light_1.png')
img_test040 = iio.imread(stem + 'test4__040.png')
 
# write it in a new format
#iio.imwrite("g4g.jpg", img)
# Out:
# /var/folders/8y/ztvmc5ys1pn64bjywt1qp4k40000gs/T/ipykernel_15648/119208319.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_dark = iio.imread(stem + 'test_dark_1.png')
# /var/folders/8y/ztvmc5ys1pn64bjywt1qp4k40000gs/T/ipykernel_15648/119208319.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_light = iio.imread(stem + 'test_light_1.png')
# ...

# %%
img_dark
# Out:
# array([[1385, 1382, 1376, ..., 1386, 1378, 1374],
#        [1394, 1384, 1385, ..., 1381, 1388, 1381],
#        [1376, 1390, 1376, ..., 1381, 1375, 1371],
#        ...,
#        [1368, 1355, 1360, ..., 1387, 1382, 1377],
#        [1368, 1388, 1383, ..., 1372, 1373, 1376],
#        [1377, 1369, 1382, ..., 1379, 1392, 1376]], dtype=int32)

# %%
img_light
# Out:
# array([[1385, 1382, 1376, ..., 1386, 1378, 1374],
#        [1394, 1384, 1385, ..., 1381, 1388, 1381],
#        [1376, 1390, 1376, ..., 1381, 1375, 1371],
#        ...,
#        [1368, 1355, 1360, ..., 1387, 1382, 1377],
#        [1368, 1388, 1383, ..., 1372, 1373, 1376],
#        [1377, 1369, 1382, ..., 1379, 1392, 1376]], dtype=int32)

# %%
plt.imshow(img_light)
plt.colorbar()
plt.show()

# %%
plt.imshow(img_light-img_dark)
plt.colorbar()
plt.show()

# %%
plt.imshow(img_light-img_test040)
plt.colorbar()
plt.show()

# %%
np.max(img_light-img_test040)
# Out:
# 995
